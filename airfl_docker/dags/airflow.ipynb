# %% [markdown]
# # Data import

# %%
import pandas as pd
import numpy as np
import os, json
from datetime import datetime

# %%
"P:/Python/GitHub/airfl_case/airfl_docker/dags/src/data/2022-12-14.json"

# %%
doc['data']
# Out:
# [{'time': '2021-01-01 00:00:00',
#   'temp': 2.8,
#   'dwpt': 2.4,
#   'rhum': 97.0,
#   'prcp': 0.0,
#   'snow': None,
#   'wdir': 180.0,
#   'wspd': 8.3,
#   'wpgt': 13.0,
#   'pres': 1004.6,
#   'tsun': 0,
#   'coco': 12},
#  {'time': '2021-01-01 01:00:00',
#   'temp': 2.3,
#   'dwpt': 1.6,
#   'rhum': 95.0,
#   'prcp': 0.1,
#   'snow': 0.0,
#   'wdir': 210.0,
#   'wspd': 10.1,
#   'wpgt': 17.0,
#   'pres': 1004.8,
#   'tsun': 0,
#   'coco': 12},
#  {'time': '2021-01-01 02:00:00',
#   'temp': 2.1,
#   'dwpt': 1.7,
#   'rhum': 97.0,
#   'prcp': 0.0,
#   'snow': None,
#   'wdir': 230.0,
#   'wspd': 9.7,
#   'wpgt': 15.0,
#   'pres': 1005.1,
#   'tsun': 0,
#   'coco': 4},
#  {'time': '2021-01-01 03:00:00',
#   'temp': 2.0,
#   'dwpt': 1.6,
#   'rhum': 97.0,
#   'prcp': 0.0,
#   'snow': None,
#   'wdir': 230.0,
#   'wspd': 5.8,
#   'wpgt': 7.0,
#   'pres': 1005.4,
#   'tsun': 0,
#   'coco': 4},
#  {'time': '2021-01-01 04:00:00',
#   'temp': 1.9,
#   'dwpt': 1.5,
#   'rhum': 97.0,
# ...

# %%
tot_name = "P:/Python/GitHub/airfl_case/airfl_docker/dags/src/data/2022-12-14.json"

with open( tot_name, 'r' ) as inputfile:
    doc = json.load( inputfile )


# convert data to csv
df = pd.DataFrame( doc['data'] )

#end_path=os.path.join( os.path.dirname(__file__), 'src/data', 'country.csv' )
#df.to_csv( end_path )
df.head()
# Out:
#                   time  temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt  \
# 0  2021-01-01 00:00:00   2.8   2.4  97.0   0.0   NaN  180.0   8.3  13.0
# 1  2021-01-01 01:00:00   2.3   1.6  95.0   0.1   0.0  210.0  10.1  17.0
# 2  2021-01-01 02:00:00   2.1   1.7  97.0   0.0   NaN  230.0   9.7  15.0
# 3  2021-01-01 03:00:00   2.0   1.6  97.0   0.0   NaN  230.0   5.8   7.0
# 4  2021-01-01 04:00:00   1.9   1.5  97.0   0.0   NaN  230.0   6.8   9.0
#
#      pres  tsun  coco
# 0  1004.6     0    12
# 1  1004.8     0    12
# 2  1005.1     0     4
# 3  1005.4     0     4
# 4  1005.8     0     7

# %%
os.getcwd()
# Out:
# 'p:\\Python\\GitHub\\airfl_case\\airfl_docker\\dags'
